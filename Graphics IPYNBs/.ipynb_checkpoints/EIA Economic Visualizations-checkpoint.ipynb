# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
pd.set_option('display.max_columns', None)
states = ["AL", "AR", "AZ","CA", "CO", "CT", "DC", "DE", "FL", "GA", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
us_state_abbrev = {'the United States':'US','Alabama': 'AL','Alaska': 'AK','American Samoa': 'AS','Arizona': 'AZ','Arkansas': 'AR','California': 'CA','Colorado': 'CO', 'Connecticut': 'CT','Delaware': 'DE','District of Columbia': 'DC', 'Florida': 'FL','Georgia': 'GA','Guam': 'GU','Hawaii': 'HI', 'Idaho': 'ID','Illinois': 'IL','Indiana': 'IN','Iowa': 'IA','Kansas': 'KS','Kentucky': 'KY','Louisiana': 'LA', 'Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI','Minnesota': 'MN','Mississippi': 'MS','Missouri': 'MO', 'Montana': 'MT','Nebraska': 'NE','Nevada': 'NV','New Hampshire': 'NH','New Jersey': 'NJ','New Mexico': 'NM','New York': 'NY','North Carolina': 'NC', 'North Dakota': 'ND','Northern Mariana Islands':'MP','Ohio': 'OH','Oklahoma': 'OK','Oregon': 'OR','Pennsylvania': 'PA','Puerto Rico': 'PR', 'Rhode Island': 'RI','South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN','Texas': 'TX','Utah': 'UT', 'Vermont': 'VT','Virgin Islands': 'VI','Virginia': 'VA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI','Wyoming': 'WY'}
abbrev_us_state = dict(map(reversed, us_state_abbrev.items()))
plt.style.use('ggplot')

api_key = 'c539dd02b98ef2d57482dfe39f7d6980'
my_url = 'http://api.eia.gov/series/?api_key=' + api_key + '&series_id='

# %%
start_year = 2000
end_year = 2019
inflation_adjustment_year = 2019
year_range = range(start_year,end_year+1)

# %%
fred_prefix = 'https://api.stlouisfed.org/fred/series/observations?series_id='
fred_api = 'd00618cf19b6ee0f138dbd06ad3b89da'
fred_series = 'CPIAUCSL'
fred_url = fred_prefix + fred_series + '&api_key='+ fred_api + '&file_type=json&frequency=a'
r = requests.get(fred_url)
json_data = r.json()

# %%
year_to_cpi = dict()
for o in list(json_data['observations']):
    year = str(o['date'][0:4])
    cpi = o['value']
    year_to_cpi[year] = cpi

# %%
inf = pd.DataFrame(columns=[str(i) for i in year_range])
cpis = [year_to_cpi[str(i)] for i in year_range]
inf.loc[0] = cpis
adjustment_denom = float(inf.loc[0,str(inflation_adjustment_year)])
iafs = [float(cpis[i])/adjustment_denom for i in range(len(year_range))]
inf.loc[1] = iafs

# %%
cpi = [0.673538,0.692509,0.703559,0.719726,0.738923,0.763797,0.788405,0.811037,0.841977,0.839282,0.853016,0.879798,0.898038,0.911204,0.925923,0.927046,0.938792,0.958862,0.982199,1]
# Out:
#   File "<ipython-input-23-d88dc6797736>", line 1
#     0.673538	0.692509	0.703559	0.719726	0.738923	0.763797	0.788405	0.811037	0.841977	0.839282	0.853016	0.879798	0.898038	0.911204	0.925923	0.927046	0.938792	0.958862	0.982199	1
#             	       ^
# SyntaxError: invalid syntax

# %%
inf.head()
# Out:
#        2000      2001      2002      2003      2004      2005      2006  \
# 0   172.192   177.042   179.867   184.000   188.908   195.267   201.558
# 1  0.673538  0.692509  0.703559  0.719726  0.738923  0.763797  0.788405
#
#        2007      2008      2009      2010      2011      2012      2013  \
# 0   207.344   215.254   214.565   218.076   224.923   229.586   232.952
# 1  0.811037  0.841977  0.839282  0.853016  0.879798  0.898038  0.911204
#
#        2014      2015      2016      2017      2018     2019
# 0   236.715   237.002   240.005   245.136   251.102  255.653
# 1  0.925923  0.927046  0.938792  0.958862  0.982199        1

# %%
def get_tags(sa):
    return ['NG.N3050'+sa+'3.A','NG.N3010'+sa+'3.A','NG.N3020'+sa+'3.A']

def get_elec_tags(sa):
    return ['SEDS.ESRCD.'+sa+'.A','SEDS.ESCCD.'+sa+'.A']

def get_gas_revenue_tags(sa):
    #Res Consumption (Mcf), Com Consumption (Mcf), Res Price ($/Tcf), Com Price ($/Tcf)
    return ['SEDS.NGRCP.'+sa+'.A', 'NG.N3010'+sa+'3.A',
            'SEDS.NGCCP.'+sa+'.A', 'NG.N3020'+sa+'3.A', 
            'SEDS.NGICP.'+sa+'.A','SEDS.NGICD.'+sa+'.A']

def return_state_EIA_data(start_year, end_year, sa, tags):
    years = range(start_year, end_year+1)
    final_output = pd.DataFrame(index=years)
    final_output.index.name = 'Year'
    for d in tags:
        try:
            r = requests.get(my_url + d)
        except:
            print('Error requesting the following API Key: ', d)
        json_data = r.json()
        json_data = json_data['series'][0]
        value_name = json_data['name'] + ' (' + json_data['units'] +')'
        json_data['data']
        temp_dict = dict()
        for pair in json_data['data']:
            temp_dict[str(pair[0])] = pair[1]
        temp_col = []
        for year in years:
            temp_val = ''
            if(str(year) in temp_dict.keys()):
                temp_val = temp_dict[str(year)]  
            temp_col.append(temp_val)
        final_output[value_name] = temp_col

    return final_output.T

# %%
dfr = return_state_EIA_data(2000,2019,'CA',get_gas_revenue_tags('CA'))
dfr.head(6)
# Out:
# Year                                                     2000       2001  \
# Natural gas consumed by (delivered to) the resi...  516730.00  512695.00
# California Price of Natural Gas Delivered to Re...       8.21      10.43
# Natural gas consumed by (delivered to) the comm...  246439.00  245795.00
# California Price of Natural Gas Sold to Commerc...       7.54       9.33
# Natural gas consumed by the industrial sector, ...  840531.00  719121.00
# Natural gas price in the industrial sector, Cal...       5.53       6.50
#
# Year                                                     2002       2003  \
# Natural gas consumed by (delivered to) the resi...  510995.00  497955.00
# California Price of Natural Gas Delivered to Re...       7.11       9.13
# Natural gas consumed by (delivered to) the comm...  238308.00  232912.00
# California Price of Natural Gas Sold to Commerc...       6.07       8.15
# Natural gas consumed by the industrial sector, ...  784853.00  821105.00
# Natural gas price in the industrial sector, Cal...       4.84       7.05
#
# Year                                                     2004       2005  \
# Natural gas consumed by (delivered to) the resi...  512046.00  483699.00
# California Price of Natural Gas Delivered to Re...       9.86      11.85
# Natural gas consumed by (delivered to) the comm...  231597.00  233082.00
# California Price of Natural Gas Sold to Commerc...       8.63      10.69
# Natural gas consumed by the industrial sector, ...  875921.00  822121.00
# Natural gas price in the industrial sector, Cal...       7.74       9.62
#
# Year                                                     2006       2007  \
# Natural gas consumed by (delivered to) the resi...  491777.00  492378.00
# California Price of Natural Gas Delivered to Re...      11.79      11.57
# Natural gas consumed by (delivered to) the comm...  244432.00  251024.00
# California Price of Natural Gas Sold to Commerc...      10.43      10.20
# Natural gas consumed by the industrial sector, ...  791763.00  797977.00
# Natural gas price in the industrial sector, Cal...       9.09       8.81
#
# Year                                                     2008       2009  \
# Natural gas consumed by (delivered to) the resi...  489304.00  480721.00
# California Price of Natural Gas Delivered to Re...      12.75       9.43
# Natural gas consumed by (delivered to) the comm...  251045.00  247775.00
# California Price of Natural Gas Sold to Commerc...      11.75       7.75
# Natural gas consumed by the industrial sector, ...  787599.00  771892.00
# Natural gas price in the industrial sector, Cal...      10.51       6.39
#
# Year                                                     2010       2011  \
# Natural gas consumed by (delivered to) the resi...  494890.00  512565.00
# California Price of Natural Gas Delivered to Re...       9.92       9.93
# Natural gas consumed by (delivered to) the comm...  247997.00  246141.00
# California Price of Natural Gas Sold to Commerc...       8.30       8.29
# Natural gas consumed by the industrial sector, ...  770837.00  752982.00
# Natural gas price in the industrial sector, Cal...       6.87       6.91
#
# Year                                                     2012       2013  \
# Natural gas consumed by (delivered to) the resi...  477931.00  481773.00
# California Price of Natural Gas Delivered to Re...       9.14       9.92
# Natural gas consumed by (delivered to) the comm...  253148.00  254845.00
# California Price of Natural Gas Sold to Commerc...       7.05       7.81
# Natural gas consumed by the industrial sector, ...  789496.00  828649.00
# Natural gas price in the industrial sector, Cal...       5.66       6.40
#
# Year                                                     2014       2015  \
# Natural gas consumed by (delivered to) the resi...  397489.00  401172.00
# California Price of Natural Gas Delivered to Re...      11.51      11.39
# Natural gas consumed by (delivered to) the comm...  237675.00  235791.00
# California Price of Natural Gas Sold to Commerc...       9.05       8.04
# Natural gas consumed by the industrial sector, ...  834167.00  822801.00
# Natural gas price in the industrial sector, Cal...       7.44       6.18
#
# Year                                                     2016       2017  \
# Natural gas consumed by (delivered to) the resi...  411828.00  431005.00
# California Price of Natural Gas Delivered to Re...      11.84      12.49
# Natural gas consumed by (delivered to) the comm...  236967.00  237352.00
# California Price of Natural Gas Sold to Commerc...       8.42       8.76
# Natural gas consumed by the industrial sector, ...  816878.00  803207.00
# Natural gas price in the industrial sector, Cal...       6.56       6.81
#
# Year                                                     2018       2019
# Natural gas consumed by (delivered to) the resi...  423915.00  464672.00
# California Price of Natural Gas Delivered to Re...      12.30      12.95
# Natural gas consumed by (delivered to) the comm...  248012.00  255981.00
# California Price of Natural Gas Sold to Commerc...       8.57       9.41
# Natural gas consumed by the industrial sector, ...  807353.00  808070.00
# Natural gas price in the industrial sector, Cal...       6.89       7.44

# %%
dfr_states = pd.DataFrame(columns=['Metric','State'] + list(dfr.columns))
for sa in states:
    try:
        dfr = return_state_EIA_data(2000,2019,sa,get_gas_revenue_tags(sa))
        res_rev = [dfr.iloc[0,i]*1000*dfr.iloc[1,i] for i in range(len(dfr.columns))]
        com_rev = [dfr.iloc[2,i]*1000*dfr.iloc[3,i] for i in range(len(dfr.columns))]
        #ind_rev = [dfr.iloc[4,i]*1030*dfr.iloc[5,i] for i in range(len(dfr.columns))]
        dfr_states.loc[len(dfr_states.index)] = ['Natural Gas Revenue ($)', sa] + [res_rev[i] + com_rev[i] for i in range(len(res_rev))]
    except:
        print(sa)

# %%
dfr_states.tail()
# Out:
#                      Metric State          2000          2001          2002  \
# 44  Natural Gas Revenue ($)    VA  1.295778e+09  1.399990e+09  1.189588e+09
# 45  Natural Gas Revenue ($)    WA  8.177189e+08  1.319152e+09  1.067117e+09
# 46  Natural Gas Revenue ($)    WV  4.079298e+08  4.510999e+08  4.423929e+08
# 47  Natural Gas Revenue ($)    WI  1.532766e+09  1.671944e+09  1.532975e+09
# 48  Natural Gas Revenue ($)    WY  1.257945e+08  1.716101e+08  1.303046e+08
#
#             2003          2004          2005          2006          2007  \
# 44  1.616425e+09  1.732693e+09  2.073309e+09  1.938333e+09  2.045020e+09
# 45  9.525534e+08  1.158413e+09  1.387627e+09  1.622525e+09  1.775577e+09
# 46  5.322404e+08  5.859542e+08  6.938615e+08  7.481772e+08  6.896467e+08
# 47  2.011395e+09  2.089166e+09  2.458968e+09  2.354033e+09  2.498749e+09
# 48  1.450264e+08  1.763790e+08  2.071808e+08  2.332568e+08  1.838924e+08
#
#             2008          2009          2010          2011          2012  \
# 44  2.149095e+09  1.865954e+09  1.780339e+09  1.631601e+09  1.402943e+09
# 45  1.749483e+09  1.856640e+09  1.463285e+09  1.637799e+09  1.472902e+09
# 46  7.418201e+08  7.243936e+08  5.635641e+08  5.060535e+08  4.543622e+08
# 47  2.886770e+09  2.251532e+09  1.979410e+09  1.963609e+09  1.608181e+09
# 48  2.253535e+08  2.019196e+08  1.903316e+08  2.009750e+08  1.672859e+08
#
#             2013          2014          2015          2016          2017  \
# 44  1.602552e+09  1.782054e+09  1.556641e+09  1.328018e+09  1.493610e+09
# 45  1.461824e+09  1.325709e+09  1.337625e+09  1.261113e+09  1.465514e+09
# 46  4.734194e+08  5.034849e+08  4.660601e+08  3.908341e+08  3.826112e+08
# 47  1.926892e+09  2.517509e+09  1.694720e+09  1.570164e+09  1.697653e+09
# 48  1.946113e+08  2.176582e+08  2.041260e+08  1.899110e+08  2.097888e+08
#
#             2018          2019
# 44  1.642810e+09  1.640427e+09
# 45  1.309479e+09  1.340441e+09
# 46  4.615875e+08  4.253790e+08
# 47  1.806116e+09  1.787896e+09
# 48  2.041533e+08  1.951742e+08

# %%
tot = ['Natural Gas Revenue (Billion $)','US Total']
add = [int(sum(dfr_states.loc[:,(i)]))/1000000000 for i in range(2000,2020)]
dfr_states.loc[49] = tot+add

# %%
dfr_states.tail()
# Out:
#                              Metric     State          2000          2001  \
# 45          Natural Gas Revenue ($)        WA  8.177189e+08  1.319152e+09
# 46          Natural Gas Revenue ($)        WV  4.079298e+08  4.510999e+08
# 47          Natural Gas Revenue ($)        WI  1.532766e+09  1.671944e+09
# 48          Natural Gas Revenue ($)        WY  1.257945e+08  1.716101e+08
# 43  1.040174e+08  1.158569e+08  1.082459e+08
# 44  1.988923e+09  2.153382e+09  2.125490e+09
# 45  2.033752e+09  1.834985e+09  1.851379e+09
# 46  7.164274e+08  8.674244e+08  8.052912e+08
# 47  2.516235e+09  2.647091e+09  2.595249e+09
# 48  6.589945e+08  6.653644e+08  6.137649e+08
# 49  1.186819e+11  1.283291e+11  1.263097e+11

# %%
res_rev = [dfr.iloc[0,i]*1000*dfr.iloc[1,i] for i in range(len(dfr.columns))]
com_rev = [dfr.iloc[2,i]*1000*dfr.iloc[3,i] for i in range(len(dfr.columns))]
#ind_rev = [dfr.iloc[4,i]*1030*dfr.iloc[5,i] for i in range(len(dfr.columns))]
#dfr.loc['Natural Gas Revenue ($)'] = [res_rev[i] + com_rev[i] + ind_rev[i] for i in range(len(res_rev))]
dfr.loc['Natural Gas Revenue ($)'] = [res_rev[i] + com_rev[i] for i in range(len(res_rev))]

# %%
dfr.tail()
# Out:
# Year                                                        2000  \
# Natural gas consumed by (delivered to) the comm...  9.752000e+03
# Wyoming Price of Natural Gas Sold to Commercial...  5.270000e+00
# Natural gas consumed by the industrial sector, ...  6.344200e+04
# Natural gas price in the industrial sector, Wyo...  3.890000e+00
# Natural Gas Revenue ($)                             1.257945e+08
#
# Year                                                        2001  \
# Natural gas consumed by (delivered to) the comm...  9.535000e+03
# Wyoming Price of Natural Gas Sold to Commercial...  8.270000e+00
# Natural gas consumed by the industrial sector, ...  6.215900e+04
# Natural gas price in the industrial sector, Wyo...  6.000000e+00
# Natural Gas Revenue ($)                             1.716101e+08
#
# Year                                                        2002  \
# Natural gas consumed by (delivered to) the comm...  1.041400e+04
# Wyoming Price of Natural Gas Sold to Commercial...  4.730000e+00
# Natural gas consumed by the industrial sector, ...  7.225100e+04
# Natural gas price in the industrial sector, Wyo...  5.020000e+00
# Natural Gas Revenue ($)                             1.303046e+08
#
# Year                                                        2003  \
# Natural gas consumed by (delivered to) the comm...  9.986000e+03
# Wyoming Price of Natural Gas Sold to Commercial...  5.840000e+00
# Natural gas consumed by the industrial sector, ...  7.641900e+04
# Natural gas price in the industrial sector, Wyo...  5.100000e+00
# Natural Gas Revenue ($)                             1.450264e+08
#
# Year                                                        2004  \
# Natural gas consumed by (delivered to) the comm...  9.916000e+03
# Wyoming Price of Natural Gas Sold to Commercial...  7.240000e+00
# Natural gas consumed by the industrial sector, ...  7.196200e+04
# Natural gas price in the industrial sector, Wyo...  6.480000e+00
# Natural Gas Revenue ($)                             1.763790e+08
#
# Year                                                        2005  \
# Natural gas consumed by (delivered to) the comm...  9.184000e+03
# Wyoming Price of Natural Gas Sold to Commercial...  9.190000e+00
# Natural gas consumed by the industrial sector, ...  7.272200e+04
# Natural gas price in the industrial sector, Wyo...  7.920000e+00
# Natural Gas Revenue ($)                             2.071808e+08
#
# Year                                                        2006  \
# Natural gas consumed by (delivered to) the comm...  9.500000e+03
# Wyoming Price of Natural Gas Sold to Commercial...  1.030000e+01
# Natural gas consumed by the industrial sector, ...  7.260700e+04
# Natural gas price in the industrial sector, Wyo...  8.550000e+00
# Natural Gas Revenue ($)                             2.332568e+08
#
# Year                                                        2007  \
# Natural gas consumed by (delivered to) the comm...  9.442000e+03
# Wyoming Price of Natural Gas Sold to Commercial...  7.890000e+00
# Natural gas consumed by the industrial sector, ...  1.024150e+05
# Natural gas price in the industrial sector, Wyo...  6.380000e+00
# Natural Gas Revenue ($)                             1.838924e+08
#
# Year                                                        2008  \
# Natural gas consumed by (delivered to) the comm...  1.018000e+04
# Wyoming Price of Natural Gas Sold to Commercial...  8.870000e+00
# Natural gas consumed by the industrial sector, ...  1.010330e+05
# Natural gas price in the industrial sector, Wyo...  7.320000e+00
# Natural Gas Revenue ($)                             2.253535e+08
#
# Year                                                        2009  \
# Natural gas consumed by (delivered to) the comm...  1.037200e+04
# Wyoming Price of Natural Gas Sold to Commercial...  8.010000e+00
# Natural gas consumed by the industrial sector, ...  9.922600e+04
# Natural gas price in the industrial sector, Wyo...  5.610000e+00
# Natural Gas Revenue ($)                             2.019196e+08
#
# Year                                                        2010  \
# Natural gas consumed by (delivered to) the comm...  1.115300e+04
# Wyoming Price of Natural Gas Sold to Commercial...  7.130000e+00
# Natural gas consumed by the industrial sector, ...  1.046220e+05
# Natural gas price in the industrial sector, Wyo...  4.760000e+00
# Natural Gas Revenue ($)                             1.903316e+08
#
# Year                                                        2011  \
# Natural gas consumed by (delivered to) the comm...  1.168000e+04
# Wyoming Price of Natural Gas Sold to Commercial...  7.290000e+00
# Natural gas consumed by the industrial sector, ...  1.131580e+05
# Natural gas price in the industrial sector, Wyo...  5.390000e+00
# Natural Gas Revenue ($)                             2.009750e+08
#
# Year                                                        2012  \
# Natural gas consumed by (delivered to) the comm...  1.048200e+04
# Wyoming Price of Natural Gas Sold to Commercial...  6.720000e+00
# Natural gas consumed by the industrial sector, ...  1.141730e+05
# Natural gas price in the industrial sector, Wyo...  4.710000e+00
# Natural Gas Revenue ($)                             1.672859e+08
#
# Year                                                        2013  \
# Natural gas consumed by (delivered to) the comm...  1.201300e+04
# Wyoming Price of Natural Gas Sold to Commercial...  6.810000e+00
# Natural gas consumed by the industrial sector, ...  1.083260e+05
# Natural gas price in the industrial sector, Wyo...  4.430000e+00
# Natural Gas Revenue ($)                             1.946113e+08
#
# Year                                                        2014  \
# Natural gas consumed by (delivered to) the comm...  1.218800e+04
# Wyoming Price of Natural Gas Sold to Commercial...  7.690000e+00
# Natural gas consumed by the industrial sector, ...  9.512000e+04
# Natural gas price in the industrial sector, Wyo...  5.660000e+00
# Natural Gas Revenue ($)                             2.176582e+08
#
# Year                                                        2015  \
# Natural gas consumed by (delivered to) the comm...  1.293700e+04
# Wyoming Price of Natural Gas Sold to Commercial...  7.430000e+00
# Natural gas consumed by the industrial sector, ...  8.056700e+04
# Natural gas price in the industrial sector, Wyo...  4.780000e+00
# Natural Gas Revenue ($)                             2.041260e+08
#
# Year                                                        2016  \
# Natural gas consumed by (delivered to) the comm...  1.342500e+04
# Wyoming Price of Natural Gas Sold to Commercial...  6.540000e+00
# Natural gas consumed by the industrial sector, ...  8.383200e+04
# Natural gas price in the industrial sector, Wyo...  3.690000e+00
# Natural Gas Revenue ($)                             1.899110e+08
#
# Year                                                        2017  \
# Natural gas consumed by (delivered to) the comm...  1.397200e+04
# Wyoming Price of Natural Gas Sold to Commercial...  6.920000e+00
# Natural gas consumed by the industrial sector, ...  1.079510e+05
# Natural gas price in the industrial sector, Wyo...  4.040000e+00
# Natural Gas Revenue ($)                             2.097888e+08
#
# Year                                                        2018          2019
# Natural gas consumed by (delivered to) the comm...  1.378700e+04  1.299600e+04
# Wyoming Price of Natural Gas Sold to Commercial...  6.610000e+00  6.300000e+00
# Natural gas consumed by the industrial sector, ...  1.213490e+05  1.116480e+05
# Natural gas price in the industrial sector, Wyo...  3.690000e+00  3.640000e+00
# Natural Gas Revenue ($)                             2.041533e+08  1.951742e+08

# %%
dfe = return_state_EIA_data(2000,2019,'GA',get_elec_tags('GA'))
dfe.head()
# Out:
# Year                                                 2000   2001   2002  \
# Electricity price in the residential sector, Ge...  22.27  22.64  22.35
# Electricity price in the commercial sector, Geo...  19.28  19.60  19.14
#
# Year                                                 2003   2004   2005  \
# Electricity price in the residential sector, Ge...  22.58  23.03  25.33
# Electricity price in the commercial sector, Geo...  19.51  20.17  22.49
#
# Year                                                 2006   2007   2008  \
# Electricity price in the residential sector, Ge...  26.11  26.66  29.09
# Electricity price in the commercial sector, Geo...  22.90  23.64  26.57
#
# Year                                                 2009   2010   2011  \
# Electricity price in the residential sector, Ge...  29.69  29.51  32.40
# Electricity price in the commercial sector, Geo...  26.21  26.54  28.92
#
# Year                                                 2012   2013   2014  \
# Electricity price in the residential sector, Ge...  32.75  33.58  34.14
# Electricity price in the commercial sector, Geo...  28.07  29.27  30.35
#
# Year                                                 2015   2016   2017  \
# Electricity price in the residential sector, Ge...  33.82  33.71  34.87
# Electricity price in the commercial sector, Geo...  28.98  28.76  29.57
#
# Year                                                 2018   2019
# Electricity price in the residential sector, Ge...  33.62  34.48
# Electricity price in the commercial sector, Geo...  28.70  29.37

# %%
dfe.index = ['Electricity Residential Price $/MMBtu',]
# Out:
# Year                                                     2000       2001  \
# Electricity price in the residential sector, Ge...  22.270000  22.640000
# Electricity price in the commercial sector, Geo...  19.280000  19.600000
# Residential Price (Inflation Adjusted to 2020 USD)   5.118107   5.349693
# Commercial Price (Inflation Adjusted to 2020 USD)    4.430943   4.631360
#
# Year                                                     2002       2003  \
# Electricity price in the residential sector, Ge...  22.350000  22.580000
# Electricity price in the commercial sector, Geo...  19.140000  19.510000
# Residential Price (Inflation Adjusted to 2020 USD)   5.365438   5.545209
# Commercial Price (Inflation Adjusted to 2020 USD)    4.594831   4.791277
#
# Year                                                     2004       2005  \
# Electricity price in the residential sector, Ge...  23.030000  25.330000
# Electricity price in the commercial sector, Geo...  20.170000  22.490000
# Residential Price (Inflation Adjusted to 2020 USD)   5.806580   6.601463
# Commercial Price (Inflation Adjusted to 2020 USD)    5.085485   5.861307
#
# Year                                                     2006       2007  \
# Electricity price in the residential sector, Ge...  26.110000  26.660000
# Electricity price in the commercial sector, Geo...  22.900000  23.640000
# Residential Price (Inflation Adjusted to 2020 USD)   7.023977   7.377815
# Commercial Price (Inflation Adjusted to 2020 USD)    6.160439   6.542069
#
# Year                                                     2008       2009  \
# Electricity price in the residential sector, Ge...  29.090000  29.690000
# Electricity price in the commercial sector, Geo...  26.570000  26.210000
# Residential Price (Inflation Adjusted to 2020 USD)   8.357398   8.502472
# Commercial Price (Inflation Adjusted to 2020 USD)    7.633416   7.505888
#
# Year                                                     2010       2011  \
# Electricity price in the residential sector, Ge...  29.510000  32.400000
# Electricity price in the commercial sector, Geo...  26.540000  28.920000
# Residential Price (Inflation Adjusted to 2020 USD)   8.589210   9.726465
# Commercial Price (Inflation Adjusted to 2020 USD)    7.724759   8.681771
#
# Year                                                     2012       2013  \
# Electricity price in the residential sector, Ge...  32.750000  33.580000
# Electricity price in the commercial sector, Geo...  28.070000  29.270000
# Residential Price (Inflation Adjusted to 2020 USD)  10.035358  10.440548
# Commercial Price (Inflation Adjusted to 2020 USD)    8.601298   9.100501
#
# Year                                                     2014       2015  \
# Electricity price in the residential sector, Ge...  34.140000  33.820000
# Electricity price in the commercial sector, Geo...  30.350000  28.980000
# Residential Price (Inflation Adjusted to 2020 USD)  10.786125  10.697980
# Commercial Price (Inflation Adjusted to 2020 USD)    9.588720   9.166986
#
# Year                                                     2016       2017  \
# Electricity price in the residential sector, Ge...  33.710000  34.870000
# Electricity price in the commercial sector, Geo...  28.760000  29.570000
# Residential Price (Inflation Adjusted to 2020 USD)  10.798295  11.408675
# Commercial Price (Inflation Adjusted to 2020 USD)    9.212666   9.674635
#
# Year                                                     2018       2019
# Electricity price in the residential sector, Ge...  33.620000  34.480000
# Electricity price in the commercial sector, Geo...  28.700000  29.370000
# Residential Price (Inflation Adjusted to 2020 USD)  11.267408  11.765064
# Commercial Price (Inflation Adjusted to 2020 USD)    9.618519  10.021460

# %%
for sa in ['CA']:
    try:
        dfe = return_state_EIA_data(2000,2019,sa,get_elec_tags(sa))
        resprice = list(dfe.iloc[0])
        comprice = list(dfe.iloc[1])
        inf2020 = list(inf.iloc[1,:])
        dfe.loc['Residential Price (Inflation Adjusted to 2020 USD)'] = [inf2020[i] * resprice[i]/2.9307107 for i in range(len(inf2020))]
        dfe.loc['Commercial Price (Inflation Adjusted to 2020 USD)'] = [inf2020[i] * comprice[i]/2.9307107 for i in range(len(inf2020))]
        year_range = range(int(dfe.columns[0]),int(dfe.columns[-1])+1)
        plt.figure(figsize=(11,6))
        plt.plot(year_range, dfe.iloc[2],label='Residential Price (cents/kWh)',linewidth='3.5',color='#323838')
        plt.plot(year_range, dfe.iloc[3], label='Commercial Price (cents/kWh)',linewidth='3.5', color='#2aa5ad')
        plt.title('Residential vs Commercial Electricity Prices in ' + abbrev_us_state[sa] + ', Inflation Adjusted USD 2020')
        plt.xticks(np.arange(year_range[0], year_range[-1], step=2), fontsize=12)
        plt.xlabel('Year')
        plt.ylabel('cents/kWh')
        #plt.yticks(np.arange(0,int(max(dfe.iloc[2])+2), step=2), fontsize=12)
        plt.legend()
        plt.show()
        plt.close()
    except:
        print('No data for', abbrev_us_state[sa])

# %%
def get_tags(sa):
    return ['NG.N3050'+sa+'3.A','NG.N3010'+sa+'3.A','NG.N3020'+sa+'3.A',
    'SEDS.ESRCD.'+sa+'.A','SEDS.ESCCD.'+sa+'.A']

# %%
dfr = return_state_EIA_data(2000,2019,sa,get_tags(sa))

# %%
def get_energy_price_data(sa):
    dfr = return_state_EIA_data(start_year,end_year,sa,get_tags(sa))
    inf_adj = list(inf.iloc[1,:])
    citygate = list(dfr.iloc[0])
    ngresprice = list(dfr.iloc[1])
    ngcomprice = list(dfr.iloc[2])
    elecresprice = list(dfr.iloc[3])
    eleccomprice = list(dfr.iloc[4])
    ia_note = '(Inflation Adjusted to ' + str(inflation_adjustment_year) + ' USD)'
    dfr.loc['Natural Gas Citygate Price $/Tcf ' + ia_note] = [inf_adj[i] * citygate[i] for i in range(len(inf_adj))]
    dfr.loc['Natural Gas Residential Price $/Tcf ' + ia_note] = [inf_adj[i] * ngresprice[i] for i in range(len(inf_adj))]
    dfr.loc['Natural Gas Commercial Price $/Tcf ' + ia_note] = [inf_adj[i] * ngcomprice[i] for i in range(len(inf_adj))]
    dfr.loc['Electricity Residential Price $/MMBtu' + ia_note] = [inf_adj[i] * elecresprice[i] for i in range(len(inf_adj))]
    dfr.loc['Electricity Commercial Price $/MMBtu' + ia_note] = [inf_adj[i] * eleccomprice[i] for i in range(len(inf_adj))]
    return dfr

# %%
dfr.tail()
# Out:
# Year                                                     2000       2001  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   3.125216   4.168904
# Natural Gas Residential Price $/Tcf (Inflation ...   5.644248   7.326745
# Natural Gas Commercial Price $/Tcf (Inflation A...   4.734972   6.364158
# Electricity Residential Price $/MMBtu(Inflation...  14.999690  15.678403
# Electricity Commercial Price $/MMBtu(Inflation ...  12.985812  13.573176
#
# Year                                                     2002       2003  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   3.201194   4.498285
# Natural Gas Residential Price $/Tcf (Inflation ...   6.937093   8.535945
# Natural Gas Commercial Price $/Tcf (Inflation A...   5.726971   7.146875
# Electricity Residential Price $/MMBtu(Inflation...  15.724546  16.251403
# Electricity Commercial Price $/MMBtu(Inflation ...  13.466122  14.041846
#
# Year                                                     2004       2005  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   5.032069   7.523401
# Natural Gas Residential Price $/Tcf (Inflation ...  10.285815  12.801238
# Natural Gas Commercial Price $/Tcf (Inflation A...   8.445895  11.273644
# Electricity Residential Price $/MMBtu(Inflation...  17.017407  19.346979
# Electricity Commercial Price $/MMBtu(Inflation ...  14.904086  17.177795
#
# Year                                                     2006       2007  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   7.387351   6.609950
# Natural Gas Residential Price $/Tcf (Inflation ...  14.482992  14.217476
# Natural Gas Commercial Price $/Tcf (Inflation A...  11.195345  10.713797
# Electricity Residential Price $/MMBtu(Inflation...  20.585244  21.622242
# Electricity Commercial Price $/MMBtu(Inflation ...  18.054465  19.172911
#
# Year                                                     2008       2009  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   7.872487   5.505691
# Natural Gas Residential Price $/Tcf (Inflation ...  15.374504  13.680299
# Natural Gas Commercial Price $/Tcf (Inflation A...  12.040274   9.819601
# Electricity Residential Price $/MMBtu(Inflation...  24.493117  24.918287
# Electricity Commercial Price $/MMBtu(Inflation ...  22.371335  21.997585
#
# Year                                                     2010       2011  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   5.058383   4.566152
# Natural Gas Residential Price $/Tcf (Inflation ...  12.940247  13.830425
# Natural Gas Commercial Price $/Tcf (Inflation A...   9.340521   9.246677
# Electricity Residential Price $/MMBtu(Inflation...  25.172491  28.505455
# Electricity Commercial Price $/MMBtu(Inflation ...  22.639034  25.443758
#
# Year                                                     2012       2013  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   3.906463   4.246210
# Natural Gas Residential Price $/Tcf (Inflation ...  14.575150  13.303576
# Natural Gas Commercial Price $/Tcf (Inflation A...   8.755866   8.547092
# Electricity Residential Price $/MMBtu(Inflation...  29.410731  30.598226
# Electricity Commercial Price $/MMBtu(Inflation ...  25.207915  26.670937
#
# Year                                                     2014       2015  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   4.805541   3.550585
# Natural Gas Residential Price $/Tcf (Inflation ...  13.379588  13.553407
# Natural Gas Commercial Price $/Tcf (Inflation A...   9.129601   7.954052
# Electricity Residential Price $/MMBtu(Inflation...  31.611012  31.352684
# Electricity Commercial Price $/MMBtu(Inflation ...  28.101764  26.865783
#
# Year                                                     2016       2017  \
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   3.445367   3.979278
# Natural Gas Residential Price $/Tcf (Inflation ...  13.668812  16.233537
# Natural Gas Commercial Price $/Tcf (Inflation A...   7.435233   8.418810
# Electricity Residential Price $/MMBtu(Inflation...  31.646679  33.435525
# Electricity Commercial Price $/MMBtu(Inflation ...  26.999659  28.353555
#
# Year                                                     2018   2019
# Natural Gas Citygate Price $/Tcf (Inflation Adj...   3.948438   3.78
# Natural Gas Residential Price $/Tcf (Inflation ...  13.731135  14.87
# Natural Gas Commercial Price $/Tcf (Inflation A...   8.024562   8.21
# Electricity Residential Price $/MMBtu(Inflation...  33.021514  34.48
# Electricity Commercial Price $/MMBtu(Inflation ...  28.189098  29.37

# %%
dfr = get_energy_price_data('GA')

# %%
for sa in ['CA']:
    try:
        df = return_state_EIA_data(2000,2019,sa,get_tags(sa))
        inf2020 = list(inf.iloc[1,:])
        citygate = list(df.iloc[0])
        resprice = list(df.iloc[1])
        comprice = list(df.iloc[2])
        df.loc['Citygate Price (Inflation Adjusted to 2020 USD)'] = [inf2020[i] * citygate[i] for i in range(len(inf2020))]
        df.loc['Residential Price (Inflation Adjusted to 2020 USD)'] = [inf2020[i] * resprice[i] for i in range(len(inf2020))]
        df.loc['Commercial Price (Inflation Adjusted to 2020 USD)'] = [inf2020[i] * comprice[i] for i in range(len(inf2020))]
        price_diff = [df.iloc[4,i]-df.iloc[3,i] for i in range(len(df.columns))]
        year_range = range(int(df.columns[0]),int(df.columns[-1])+1)
        size_factor = 22
        plt.figure(figsize=(size_factor,size_factor*6/11))
        lw = size_factor * 3.5/11
        fs = size_factor * 12/11
        plt.plot(year_range, price_diff, ':', label='Revenues Excluding City Gate Price ($/TCF)',linewidth=lw, color='#153b66')
        plt.plot(year_range, df.iloc[3],label='City Gate Price ($/TCF)',linewidth=lw,color='#323838')
        plt.plot(year_range, df.iloc[4], label='Residential Price ($/TCF)',linewidth=lw, color='#2aa5ad')
        #plt.plot(year_range, df.iloc[5], label='Commercial Price ($/TCF)',linewidth=lw, color='black')
        plt.title('Residential vs City Gate Natural Gas Prices in ' + abbrev_us_state[sa] + ', Inflation Adjusted USD 2020', fontsize=fs*1.25)
        plt.xticks(np.arange(year_range[0], year_range[-1], step=2), fontsize=fs)
        plt.xlabel('Year', fontsize=fs)
        plt.ylabel('$/TCF', fontsize=fs)
        plt.yticks(np.arange(0,int(max(df.iloc[4])+2), step=2), fontsize=fs)
        plt.legend(fontsize=fs)
        plt.show()
        plt.close()
    except:
        print('No data for', abbrev_us_state[sa])

# %%
list(inf.loc[1])
# Out:
# [0.6735379596562528,
#  0.692508986790689,
#  0.7035591211524996,
#  0.7197255655126285,
#  0.7389234626622805,
#  0.7637970217443175,
#  0.7884045952912737,
#  0.8110368350850568,
#  0.8419772112981267,
#  0.8392821519794409,
#  0.853015611003978,
#  0.8797980074554181,
#  0.8980375743683823,
#  0.9112038583548795,
#  0.9259230284800101,
#  0.9270456439001303,
#  0.9387920345155347,
#  0.9588622077581722,
#  0.9821985269095219,
#  1.0]

# %%
df2 = pd.concat([df.iloc[1,:],df.iloc[4,:]],axis=1)
df2 = df2.T
df2.index = ['CA Res Gas Price ($/TCF)', 'CA Res Gas Price ($/TCF) 2019-Inflation Adjusted']
df2.loc['Inflation Adjustment Factors'] = list(inf.loc[1])
df2.loc['CA Res Gas Price ($/TCF)'] = [str(i)[0:5] for i in df2.loc['CA Res Gas Price ($/TCF)']]
df2.loc['CA Res Gas Price ($/TCF) 2019-Inflation Adjusted'] = [str(i)[0:5] for i in df2.loc['CA Res Gas Price ($/TCF) 2019-Inflation Adjusted']]
df2.loc['Inflation Adjustment Factors'] = [str(i)[0:5] for i in df2.loc['Inflation Adjustment Factors']]

df2.head()
# Out:
# Year                                               2000   2001   2002   2003  \
# CA Res Gas Price ($/TCF)                           8.21  10.43   7.11   9.13
# CA Res Gas Price ($/TCF) 2019-Inflation Adjusted  5.529  7.222  5.002  6.571
# Inflation Adjustment Factors                      0.673  0.692  0.703  0.719
#
# Year                                               2004   2005   2006   2007  \
# CA Res Gas Price ($/TCF)                           9.86  11.85  11.79  11.57
# CA Res Gas Price ($/TCF) 2019-Inflation Adjusted  7.285  9.050  9.295  9.383
# Inflation Adjustment Factors                      0.738  0.763  0.788  0.811
#
# Year                                               2008   2009   2010   2011  \
# CA Res Gas Price ($/TCF)                          12.75   9.43   9.92   9.93
# CA Res Gas Price ($/TCF) 2019-Inflation Adjusted  10.73  7.914  8.461  8.736
# Inflation Adjustment Factors                      0.841  0.839  0.853  0.879
#
# Year                                               2012   2013   2014   2015  \
# CA Res Gas Price ($/TCF)                           9.14   9.92  11.51  11.39
# CA Res Gas Price ($/TCF) 2019-Inflation Adjusted  8.208  9.039  10.65  10.55
# Inflation Adjustment Factors                      0.898  0.911  0.925  0.927
#
# Year                                               2016   2017   2018   2019
# CA Res Gas Price ($/TCF)                          11.84  12.49   12.3  12.95
# CA Res Gas Price ($/TCF) 2019-Inflation Adjusted  11.11  11.97  12.08  12.95
# Inflation Adjustment Factors                      0.938  0.958  0.982    1.0

# %%
price_diff = [df.iloc[4,i]-df.iloc[3,i] for i in range(len(df.columns))]
year_range = range(int(df.columns[0]),int(df.columns[-1])+1)
plt.figure(figsize=(11,6))
plt.plot(year_range, price_diff, ':', label='Revenues Excluding City Gate Price ($/TCF)',linewidth='3.5', color='#153b66')
plt.plot(year_range, df.iloc[3],label='City Gate Price ($/TCF)',linewidth='3.5',color='#323838')
plt.plot(year_range, df.iloc[4], label='Residential Price ($/TCF)',linewidth='3.5', color='#2aa5ad')
plt.title('Residential vs City Gate Natural Gas Prices in ' + abbrev_us_state[sa] + ', Inflation Adjusted USD 2020')
plt.xticks(np.arange(year_range[0], year_range[-1], step=2), fontsize=12)
plt.xlabel('Year')
plt.ylabel('$/TCF')
plt.yticks(np.arange(0,17, step=2), fontsize=12)
plt.legend()
plt.show()

# %%
#Import FRED CPI Inflation Adjustment Data
fred_prefix = 'https://api.stlouisfed.org/fred/series/observations?series_id='
fred_api = 'd00618cf19b6ee0f138dbd06ad3b89da'
fred_series = 'CPIAUCSL'
fred_url = fred_prefix + fred_series + '&api_key='+ fred_api + '&file_type=json&frequency=a'
r = requests.get(fred_url)
json_data = r.json()

year_to_cpi = dict()
for o in list(json_data['observations']):
    year = str(o['date'][0:4])
    cpi = o['value']
    year_to_cpi[year] = cpi

#Create a DataFrame with CPIs and Inflation Adjustments
inf = pd.DataFrame(columns=[str(i) for i in year_range])
cpis = [year_to_cpi[str(i)] for i in year_range]
inf.loc[0] = cpis
adjustment_denom = float(inf.loc[0,str(inflation_adjustment_year)])
iafs = [float(cpis[i])/adjustment_denom for i in range(len(year_range))]
inf.loc[1] = iafs

# %%
inf.head()
# Out:
#        2000      2001      2002      2003      2004      2005      2006  \
# 0   172.192   177.042   179.867   184.000   188.908   195.267   201.558
# 1  0.673538  0.692509  0.703559  0.719726  0.738923  0.763797  0.788405
#
#        2007      2008      2009      2010      2011      2012      2013  \
# 0   207.344   215.254   214.565   218.076   224.923   229.586   232.952
# 1  0.811037  0.841977  0.839282  0.853016  0.879798  0.898038  0.911204
#
#        2014      2015      2016      2017      2018     2019
# 0   236.715   237.002   240.005   245.136   251.102  255.653
# 1  0.925923  0.927046  0.938792  0.958862  0.982199        1

# %%
inf.loc[0,str(inflation_adjustment_year)]
# Out:
# '255.653'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

start_year = 2000
end_year = 2019
inflation_adjustment_year = 2019
year_range = range(start_year,end_year+1)

api_key = 'c539dd02b98ef2d57482dfe39f7d6980'
my_url = 'http://api.eia.gov/series/?api_key=' + api_key + '&series_id='


#Import FRED CPI Inflation Adjustment Data
fred_prefix = 'https://api.stlouisfed.org/fred/series/observations?series_id='
fred_api = 'd00618cf19b6ee0f138dbd06ad3b89da'
fred_series = 'CPIAUCSL'
fred_url = fred_prefix + fred_series + '&api_key='+ fred_api + '&file_type=json&frequency=a'
r = requests.get(fred_url)
json_data = r.json()

year_to_cpi = dict()
for o in list(json_data['observations']):
    year = str(o['date'][0:4])
    cpi = o['value']
    year_to_cpi[year] = cpi

#Create a DataFrame with CPIs and Inflation Adjustments
inf = pd.DataFrame(columns=[str(i) for i in year_range])
cpis = [year_to_cpi[str(i)] for i in year_range]
inf.loc[0] = cpis
adjustment_denom = float(inf.loc[0,str(inflation_adjustment_year)])
iafs = [float(cpis[i])/adjustment_denom for i in range(len(year_range))]
inf.loc[1] = iafs

def get_tags(sa):
    return ['NG.N3050'+sa+'3.A','NG.N3010'+sa+'3.A','NG.N3020'+sa+'3.A',
    'SEDS.ESRCD.'+sa+'.A','SEDS.ESCCD.'+sa+'.A']

def return_state_EIA_data(start_year, end_year, sa, tags):
    years = range(start_year, end_year+1)
    final_output = pd.DataFrame(index=years)
    final_output.index.name = 'Year'
    for d in tags:
        try:
            r = requests.get(my_url + d)
        except:
            print('\n\nError requesting the following API Key: ', d,'\n\n')
        json_data = r.json()
        json_data = json_data['series'][0]
        value_name = json_data['name'] + ' (' + json_data['units'] +')'
        json_data['data']
        temp_dict = dict()
        for pair in json_data['data']:
            temp_dict[str(pair[0])] = pair[1]
        temp_col = []
        for year in years:
            temp_val = ''
            if(str(year) in temp_dict.keys()):
                temp_val = temp_dict[str(year)]  
            temp_col.append(temp_val)
        final_output[value_name] = temp_col
    return final_output.T

def get_energy_price_data(sa):
    df = return_state_EIA_data(start_year,end_year,sa,get_tags(sa))
    inf_adj = list(inf.iloc[1,:])
    ia_note = '(Inflation Adjusted to ' + str(inflation_adjustment_year) + ' USD)'
    df.loc['Natural Gas Citygate Price $/Tcf ' + ia_note] = [inf_adj[i] * list(df.iloc[0])[i] for i in range(len(inf_adj))]
    df.loc['Natural Gas Residential Price $/Tcf ' + ia_note] = [inf_adj[i] * list(df.iloc[1])[i] for i in range(len(inf_adj))]
    df.loc['Natural Gas Commercial Price $/Tcf ' + ia_note] = [inf_adj[i] * list(df.iloc[2])[i] for i in range(len(inf_adj))]
    df.loc['Electricity Residential Price $/MMBtu ' + ia_note] = [inf_adj[i] * list(df.iloc[3])[i] for i in range(len(inf_adj))]
    df.loc['Electricity Commercial Price $/MMBtu ' + ia_note] = [inf_adj[i] * list(df.iloc[4])[i] for i in range(len(inf_adj))]
    df.loc['Inflation Adjustment Factor (' + str(inflation_adjustment_year) + ')'] = inf_adj
    return df

# %%
dfga = get_energy_price_data('GA')
